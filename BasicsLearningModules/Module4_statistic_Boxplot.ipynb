# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


imdb_Example=pd.read_csv("data/IMDB-Movie-Data.csv")
imdb_Example=imdb_Example.set_index("Rating")
y=imdb_Example["Runtime (Minutes)"]
plt.title("boxplot")
plt.boxplot(y)
plt.show()

# %%
plt.boxplot(imdb_Example[""])
plt.show()
